# %%
import json
import urllib
from urllib.parse import urlparse
import httplib2 as http 
import pandas as pd

# %%
#Passenger Volume by Bus Stops

if __name__=="__main__":
 #Authentication parameters
    headers = { 'AccountKey' : 'pNhcp/4TTU69vdvLbYsuuw==','accept' : 'application/json'} #this is by default
    method = 'GET'
    body = ''

    #API parameters
    uri = 'http://datamall2.mytransport.sg/' #Resource URL
    path = 'ltaodataservice/PV/Bus'
    #Build query string & specify type of API call
    target = urlparse(uri + path)

     #Get handle to http
    h = http.Http()
    #Obtain results
    response, content = h.request(target.geturl(),method,body,headers)

    #extract in json
    jsonObj = json.loads(content)
    #print (json.dumps(jsonObj['value'], sort_keys=True, indent=4))
    print(jsonObj)
# Out:
# {'odata.metadata': 'http://datamall2.mytransport.sg/ltaodataservice/$metadata#FarecardBatch', 'value': [{'Link': 'https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202002/transport_node_bus_202002.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkcwRQIhANPd7in2LSDFrSyQwErC6nrAzFepo9ka0Wo08ieNsH6iAiBuGhLw9rQ6ULz0tMqnMUhfL41rvTawZTBKbyMzCV3EVyqsAwjk%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAEaDDM0MDY0NTM4MTMwNCIMG3VOWXe6NQntEojBKoAD9NGvBVT5rqTqiJe7lbJDh43Geeb2oXkx2uB%2BynDS%2Fp%2Br0TZ18pRzw5A8qOSsv1wu%2FFE65R34OeNkqGTUx01pVK3vJ8brdKhC1XPrw773xDJCElrlT9xUlPa0%2BjjqNfO7Gm3xGuJxSUD8BgwXWU7uUNUwK5Qlq5BdJxNsCChMjpAz%2BYJ%2BsVD0O2u67nUFB7JVot3ePx0AMSzqoqNdfCwUUBvgqrYHVhBdNwsw1z%2FKko3yiDUpOuILR%2FRR1eNmm9YcgP3blkf3FOMjDdMfOtd2l5VXbhIv5lY7Mrgl5pAAJwOqhO%2FXw%2BeWfmTrwR6Opgpk%2Bzhd3F76Fff%2FX3%2Be8Houe3iX7vKbB5vl8qxiGQ2Bvix1dwpeD0aqHvYnpBI6jv4wjOpQACW1gyeZcHx3E2NCFkHIGMZNFt2uH1j44BAty2YraXTbxCjeNfB4KGb6jBVqVnNtgyv9iknTOdzHORuZ%2BpQ2ULd%2FyYNH9zLUzO%2Fm56vgqCOYu8AdcS0rAYvzxXO6MJ3X0PMFOusBa2LlfgmxmBjlZmP7kNjIErAp%2FIp2WXx%2B6JyKyZTrWEfagQfrkNoRD9vA8I4x08RfJJfEYRVZdFhL6PqDqSK0XIZfHQEd51FQzt7Alg1Gt9950PAeJlSBtFcEOqR%2FzlSzx2VcMkYDUgp8pOJu1waQ90yxWii0pyFJ6RkC4vWvB3bY4tNDpklSwQHTlw%2FT%2Fh93pvnehq3ZHjECS%2BIBSPsEmO8P05%2Fg5v96AgD6HnNnRUH1EYdUPjwppE%2BfFgvmP3Leyuy5LJJy7ksGwoAu4%2FpOdzc5%2BES2YzUqhU5zdLoMEJ%2FD7wXOlrFqIsyMwg%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20200320T033010Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4HHEGC6TG%2F20200320%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=9a8a84dfb10d8225f2e7553f219ae889ffb8db0ddcbca3e0cc04094de3791259'}]}

# %%
#Passenger Volume by Origin Destination Bus Stop

if __name__=="__main__":
 #Authentication parameters
    headers = { 'AccountKey' : 'pNhcp/4TTU69vdvLbYsuuw==','accept' : 'application/json'} #this is by default
    method = 'GET'
    body = ''

    #API parameters
    uri = 'http://datamall2.mytransport.sg/' #Resource URL
    path = 'ltaodataservice/PV/ODBus'
    #Build query string & specify type of API call
    target = urlparse(uri + path)

     #Get handle to http
    h = http.Http()
    #Obtain results
    response, content = h.request(target.geturl(),method,body,headers)

    #extract in json
    jsonObj = json.loads(content)
    #print (json.dumps(jsonObj['value'], sort_keys=True, indent=4))
    print(jsonObj)
# Out:
# {'odata.metadata': 'http://datamall2.mytransport.sg/ltaodataservice/$metadata#FarecardBatch', 'value': [{'Link': 'https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202002/origin_destination_bus_202002.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkcwRQIhANdGLEW6q8oECFKoHR%2BLVK4V0p4yIa6jHeGmbEOzssB4AiBul4KaQnEQU1AKWk2gBNb60g2cJ0pWlDHSB7Isfy52YCqsAwjk%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAEaDDM0MDY0NTM4MTMwNCIMJRgoWbz7hexIXQUTKoADqw0aKntoGNUS6UDHArmOErqgXOl%2FRBgIAOixfR%2F8nfuwNf25v6ZV%2BhcjJJZBOiZCrI8JishMPofiD4CuN09KdZpWZCWd48HkIAOHkcEZNm2ABgwCAraI9pFe9bCoC3nltBPMILjVIJ2GdN8l%2BfPfjKTWB9BaXlNpra%2BCiyV5D%2FYqpLDFioBy3nuoqzOjsE0iw2oNzzwKyFGJxlAVFXPT9LCKO8UBmQWAMJ%2FuFwVPlArhuLxIMz8y%2BRPllVUT1BrS%2BaATWBjUL6qe9sC5AOlgKYsHU9gUWZN%2F%2B1Jv1%2FOKpwf%2FXb38KV5Tl1yr9urfxorN6dftHoOj%2BrKufQGx5fUf6DwqyesA0yljY%2FfrmmESLs6kfcdEvTjRrUyLDA97mQj9rw2pZt0CVrBoflXn0EuO3YrtNw0jZJGMMdTjPRssHrApO1JMCxy26i9CtEuopJ8AM8%2BzTBm4OpThpKjzlYbQCqXMZXOejqIO1LNoED4tcz%2F%2BdmfGpj4AZhc32J6Q9j5%2FMJ3X0PMFOusBBLuR1sJ88Y30Xg3y6YDU6tQN3A5McN%2BSUYXUznuXmGKGbCKrMS0absEQ%2Bs%2BKK0WYFgS80TP5b6CaEhBKBfzbuTyn8B7YViSpgfqI8hoabc%2BoT2Cd5ecXrysf1ePcB2v5NWW7fJ6EKWQQKZoSSQtCQcbqdK2WZ%2BzkBnawVR1ciMvjYVMYlkOOubAbaDGKBXdxgqkMsJNWLGRKuvlj%2B1i6s%2BZ7Cpj7SMMk8v4eZekXo97aTh2aerapLbULbD3nZgTgAOsEHbD2uYCJ0soYPlOUZvcKGJ9%2FcHhEeQfXI%2B3tOKciVPVcwReQmn3IaA%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20200320T032910Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4A2ADVC3O%2F20200320%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=5cca86db3b63c1a4cf48105d5c482e5bf6ca55cad26cfe7d00a3a68376d3dadc'}]}

# %%
#Busstops
bus_stop_overall = pd.DataFrame(columns=['BusStopCode', 'Description', 'Latitude', 'Longitude', 'RoadName'])

if __name__=="__main__":
 #Authentication parameters
    headers = { 'AccountKey' : 'pNhcp/4TTU69vdvLbYsuuw==','accept' : 'application/json'} #this is by default
    method = 'GET'
    body = ''

    # each API call only return 500 rows, hence writing a loop to extract more data
    for i in range (0,6000,500):

        #API parameters
        print(i)
        uri = 'http://datamall2.mytransport.sg/' #Resource URL
        path = 'ltaodataservice/BusStops?$skip='
        #Build query string & specify type of API call
        target = urlparse(uri + path+str(i))

         #Get handle to http
        h = http.Http()
        #Obtain results
        response, content = h.request(target.geturl(),method,body,headers)

        #extract in json
        jsonObj = json.loads(content)
        #print (json.dumps(jsonObj['value'], sort_keys=True, indent=4))
        busstops = pd.DataFrame.from_dict(jsonObj['value'])
          
        #append to overall dataframe
        bus_stop_overall = bus_stop_overall.append(busstops, ignore_index = True)

bus_stop_overall.to_csv('data/busstops.csv')
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500

# %%
bus_stop_overall.tail()
# Out:
#      BusStopCode             Description  Latitude   Longitude  \
# 5036       99139                   Blk 5  1.388195  103.987234
# 5037       99161   Bef Changi Beach CP 3  1.390262  103.992957
# 5038       99171       Changi Beach CP 2  1.391128  103.991021
# 5039       99181  Bef S'pore Aviation Ac  1.387754  103.988503
# 5040       99189      S'pore Aviation Ac  1.388414  103.989716
#
#                RoadName
# 5036  Changi Village Rd
# 5037          Nicoll Dr
# 5038          Nicoll Dr
# 5039      Telok Paku Rd
# 5040      Telok Paku Rd
